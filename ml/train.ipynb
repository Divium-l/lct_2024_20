# %%
import pandas as pd
import numpy as np
import torch
import plot_helper
from catboost import CatBoostClassifier, Pool
from transformers import AutoModel
from tqdm.notebook import tqdm

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.utils.class_weight import compute_class_weight

import warnings

warnings.filterwarnings('ignore')

df = pd.read_csv("data/train.csv")
print(df.columns.tolist())
name_columns = pd.read_csv("data/train_labels.csv")
# Out:
# ['axrlqygbssxu', 'firstname', 'lon', 'firm', 'fxvspjlbgrhm', 'jqfyjomipilf', 'location_id', 'phone_number', 'eosogjttsvtt', 'org_id', 'state', 'aevtkbjhhryq', 'customer_iban', 'departmentsid', 'switching_center_lat', 'relationship_status', 'phone_no', 'aoprdggmbtuz', 'wage', 'customer_email', 'country', 'family_email', 'countyname', 'vcqcujsmuukw', 'ywpjaeadqwwj', 'active', 'rrubbcpjrqht', 'kgazxjkrlqja', 'benefitdaycare', 'iinelubpyelh', 'gbhwunppuetx', 'lat', 'province', 'kdxrpomztopy', 'neighbourhood', 'jtklraxdukre', 'nkoyzuojoair', 'phone_ext', 'ssn', 'dqshzbqqvqdc', 'person_surname', 'lng', 'ukofatwbaafw', 'ijfsukxdjfhd', 'flikvuanjlbz', 'bndecuspucsy', 'datum_izvestaja', 'last_name', 'road_name', 'kozakymqwsyw', 'uniquemastercitizennumber', 'road_name.1', 'geo_latitude', 'street', 'homephone', 'uniform_civil_number', 'tzvshsmubghm', 'company_name', 'userid', 'cell_phone_number', 'psspt id', 'pwd_argon', 'phone', 'zudlvyipnzyv', 'husipigzonkk', 'aagvnhasmkig', 'customer_name', 'personal_identification_number', 'sms identifier', 'phone_ext.1', 'company_name.1', 'street.1', 'phone_no.1', 'passwordquestion', 'next_rset_dt', 'sdnasqkqptur', 'rveiiujvveoc', 'wixyokckgksv', 'kwwjshqmkqyy', 'customer_address_id', 'nzefdkmiiwyl', 'rdejzegcgyfj', 'family_contact_email', 'emailid', 'luhuibvuxihl', 'yshbksmmuokv', 'cell_phone_number.1', 'city', 'phone_number.1', 'active_at', 'cdbyibyrnhhe', 'hnvsnnkewlhw', 'zpcufwyrwjwe', 'bhpofbgbatko', 'address_line_2', 'store_id', 'date_time_activated', 'lat.1', 'passwordanswer', 'msgqleuliisn', 'call_location_lat', 'last_name.1', 'paid', 'yhzmfcqjwqde', 'wsjgwblobslz', 'ssvutvttkgop', 'putlesnmbnfl', 'aefoxiqjscpw', 'road_name.2', 'fax', 'lsclcshrkgqt', 'benefithealthinsurance', 'akiiohuufjol', 'vbwffndkojcp', 'fax.1', 'contact_email', 'kugzndtesrqe', 'qnyaykaksncj', 'organization', 'banksuffix', 'haupfnryhrgq', 'country.1', 'zrcukertkonn', 'ezwkudurisab', 'person_last_name', 'kccpfobsieei', 'state.1', 'street.2', 'date_employed_to', 'sum_profit', 'customer_name.1', 'sms', 'latitude', 'customer_lname', 'street.3', 'region', 'street.4', 'iintinbwwhjc', 'mzwdmlhjdfwf', 'married', 'ckoesjafeubh', 'oowffmhbbakp', 'qhotkhsodhaf', 'dakpjawcjfpn', 'vqmhkaolrubg', 'spxiukldmeof', 'tkxvlqswlpqx', 'road_name.3', 'customer_iban.1', 'organization.1', 'lat.2', 'extension', 'dytdfmxwosdh', 'pager', 'churn', 'useremail', 'zip_code', 'postal_code', 'userid.1', 'managersid', 'last_update', 'vmwfwqqsnoic', 'tlkmszafejmx', 'country_code', 'flerbbbqqjoa', 'sutbddztgxhl', 'mobilephonenumber', 'dsc', 'kkutwrzyqmep', 'fzcpjefhgmdt', 'geo_longitude', 'birthday_id', 'ggyyjittwqkq', 'employee', 'call_location_lng', 'company', 'street.5', 'fwkcikgbmnbm', 'identification_code', 'state_disctrict', 'grbilkhmeyqe', 'pwd_argon.1', 'ddugstbrmunq', 'email_sid', 'jropbpqkooeb', 'gpo', 'gvsikerlsdbd', 'uniform_civil_number.1', 'organization.2', 'deleted', 'mvgdxwhvwzsg', 'resident_registration_number', 'sid', 'date_employed_from', 'national_identification_number', 'personal_identification_code', 'number_called_type_sid', 'road', 'emailladdresssid', 'jukdpbcyhnps', 'yfapopnlspfs', 'benefitdaycare.1', 'employeeid', 'given_name', 'date_of_birth', 'date_account_closed', 'ttxaqovswobn', 'date_left_employment', 'extension.1', 'longitude', 'steuer_id', 'email_address_sid', 'personal_identity_code', 'bapsyfjsyjko', 'contact_last', 'mobilephonenumber.1', 'accuracy_in_meters', 'customer_email.1', 'emailladdress', 'consent_given', 'managersid.1', 'orderid', 'person_name', 'organization.3', 'verification details', 'fname', 'start_date', 'insee_code', 'accuracy_in_meters.1', 'bpfnuduvuckg', 'ntnthimpauko', 'hzjhrfcxvpuw', 'province.1', 'extension.2', 'ixeorvghirzg', 'caonciqiwtpe', 'benefitlifeinsurance', 'at', 'telephone', 'family_contact', 'switching_center_lat.1', 'steuer_id.1', 'ssn.1', 'rmcehbcuisfv', 'mobilephonenumber.2', 'ynhvrpjtcrgr', 'idoedwjukcsu', 'extension.3', 'dateupdated', 'sms.1', 'illlpdiowtyk', 'sin', 'ovgfpjashaaj', 'inoa ...

# %%
# add type data how catigorical feature for catboost 
# add name columns for embedding
# add custom features (*)
# size in database
# change model embedding
# clean dataset

# %%
train_dataset = pd.DataFrame(
    zip(df.columns.tolist(), name_columns.label.values.tolist()),
    columns=["name_column", "type_column"]
)
train_dataset["label"] = (train_dataset.type_column != "Other_data").astype(int)
print(train_dataset)
# Out:
#             name_column          type_column  label
# 0          axrlqygbssxu                 Date      1
# 1             firstname               Person      1
# 2                   lon          Geolocation      1
# 3                  firm  Organization,Person      1
# 4          fxvspjlbgrhm         Phone_number      1
# ...                 ...                  ...    ...
# 18811  consent_given.38           Other_data      0
# 18812    employee_id.78           Other_data      0
# 18813   password_hash.4           Other_data      0
# 18814        geo_lat.48          Geolocation      1
# 18815             at.24                  GPE      1
#
# [18816 rows x 3 columns]

# %%
features = [",".join(df[name_col].astype(str).values) for name_col in train_dataset.name_column]

# %%
model = AutoModel.from_pretrained('jinaai/jina-embeddings-v2-base-code', max_length=256, trust_remote_code=True)

# %%
#TODO: в энкод можно переедавать срахзу список
list_embeddings = []
for s in tqdm(features[:100]):
    emb = model.encode([s])
    list_embeddings.append(emb)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
arr_embeddings = np.concatenate(list_embeddings)

# %%
train_dataset.iloc[:100].label.value_counts()
# Out:
# label
# 1    77
# 0    23
# Name: count, dtype: int64

# %%
train_dataset.iloc[:1000].label.value_counts()
# Out:
# label
# 1    797
# 0    203
# Name: count, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(arr_embeddings, train_dataset.iloc[:100].label, test_size=0.1)
print(train_dataset)
print(X_test)
# Out:
#             name_column          type_column  label
# 0          axrlqygbssxu                 Date      1
# 1             firstname               Person      1
# 2                   lon          Geolocation      1
# 3                  firm  Organization,Person      1
# 4          fxvspjlbgrhm         Phone_number      1
# ...                 ...                  ...    ...
# 18811  consent_given.38           Other_data      0
# 18812    employee_id.78           Other_data      0
# 18813   password_hash.4           Other_data      0
# 18814        geo_lat.48          Geolocation      1
# 18815             at.24                  GPE      1
#
# [18816 rows x 3 columns]
# [[-0.05521008  0.9677746  -1.0954524  ... -0.05970605  0.09508912
#   -0.29939735]
#  [ 0.2442877   0.58980274  0.00636479 ... -0.29847014  0.08918569
#    0.35959253]
#  [ 0.06960289  0.87066245 -0.22652654 ... -0.03413647 -0.20760293
#   -0.24642873]
#  ...
#  [ 0.16789044  0.930343   -0.4221397  ...  0.40673962  0.8023587
#    0.2421939 ]
#  [ 0.04156041  1.1478919  -0.27831984 ... -0.45805326  0.32432052
#    0.17747995]
#  [-0.31039602  1.002198   -0.23049404 ... -0.5069747   0.36974797
#    0.15210669]]

# %%
weights = compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)

# %%
model = CatBoostClassifier(
    iterations=1000,
    depth=2, 
    learning_rate=0.01, 
    loss_function='Logloss', 
    eval_metric='AUC',
    class_weights=weights, 
    od_type="Iter", 
    od_wait=300
)

# %%
model.fit(
    X_train, 
    y_train,
    eval_set=(X_test, y_test), 
    use_best_model=True, 
    # cat_features=f_cat, f_cat - индексы колонок с категорилаьными фичи
    plot=True, 
    metric_period=100,
    verbose=True
)
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# Warning: Overfitting detector is active, thus evaluation metric is calculated on every iteration. 'metric_period' is ignored for evaluation metric.
# 0:	test: 0.0555556	best: 0.0555556 (0)	total: 61.1ms	remaining: 1m 1s
# 100:	test: 0.7777778	best: 0.8333333 (2)	total: 212ms	remaining: 1.89s
# 200:	test: 0.8888889	best: 0.8888889 (194)	total: 333ms	remaining: 1.32s
# 300:	test: 0.8888889	best: 0.8888889 (194)	total: 451ms	remaining: 1.05s
# 400:	test: 0.8888889	best: 0.8888889 (194)	total: 583ms	remaining: 871ms
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8888888889
# bestIteration = 194
#
# Shrink model to first 195 iterations.

# %%
plot_helper.plotTableAUCRoc(model, X_test, y_test, thresholder=0.5, normalize=False)
# Out:
# F1 =  0.875
# Confusion matrix, without normalization
# (0.8888888888888888, 0.875)

# %%
pd.Series(model.predict_proba(X_test)[:, 1]).hist()
# Out:
# <Axes: >

# %%
model.predict_proba(X_test)
# Out:
# array([[0.10985249, 0.89014751],
#        [0.09833364, 0.90166636],
#        [0.12852584, 0.87147416],
#        [0.57412929, 0.42587071],
#        [0.23126794, 0.76873206],
#        [0.08833596, 0.91166404],
#        [0.13543118, 0.86456882],
#        [0.63525163, 0.36474837],
#        [0.23830456, 0.76169544],
#        [0.57688594, 0.42311406]])

# %%
model.predict_proba(X_test[:10])
# Out:
# array([[0.10985249, 0.89014751],
#        [0.09833364, 0.90166636],
#        [0.12852584, 0.87147416],
#        [0.57412929, 0.42587071],
#        [0.23126794, 0.76873206],
#        [0.08833596, 0.91166404],
#        [0.13543118, 0.86456882],
#        [0.63525163, 0.36474837],
#        [0.23830456, 0.76169544],
#        [0.57688594, 0.42311406]])

# %%
model.save_model("name")

# %%
new_m = CatBoostClassifier()

# %%
new_w = new_m.load_model("name")

# %%
r = new_w.predict(arr_embeddings)

# %%
for i in range(len(r)):
    print(bool(r[i]))
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# False
# False
# False
# True
# False
# True
# True
# False
# True
# True
# True
# True
# True
# True
# False
# True
# True
# False
# False
# False
# True
# True
# False
# True
# False
# True
# True
# False
# False
# True
# True
# True
# True
# True
# True
# True
# True
# True
# False
# True
# True
# True
# True
# True
# True
# True
# True
# False
# True
# True
# False
# True
# False
# True
# False
# True
# True
# True
# True
# True
# True
# True
# False
# False
# True
# True
# True
# True
# True
# True
# True
# True
# True
# False
# True
# True
# True
# True
# True
# False
# False
# True
# True
# True
# False
# True
# True
# False
# True
